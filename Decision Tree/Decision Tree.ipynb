# %%
import pandas as pd

# %%
dataset = pd.read_csv("50_Startups.csv")

# %%
dataset = pd.get_dummies(dataset, dtype = int,drop_first=True)

# %%
#assign input and output columns
independent=dataset[['R&D Spend', 'Administration', 'Marketing Spend','State_Florida', 'State_New York']]

# %%
dependent=dataset[['Profit']]

# %%
#splitting Train set and test set
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
#Standardaization to imporve the model

from sklearn.tree import DecisionTreeRegressor

regressor = DecisionTreeRegressor(criterion = 'poisson', splitter = 'best', max_features= 'log2')
regressor.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='poisson', max_features='log2')

# %%
import matplotlib.pyplot as plt
from sklearn import tree
tree.plot_tree(regressor)
plt.show
#matplotlib for graph purpose
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Evalution phase
y_pred = regressor.predict(x_test)
from sklearn.metrics import r2_score
r_score = r2_score(y_test,y_pred)
r_score
# Out:
# 0.7311001518235704

# %%
#there are lot of hypertuning parameters to improve the model and then finalize the model
